# %% [markdown]
# # FEATURE ENGINEERING
# ### Fraud Detection System Development using Deep Neural Network for Reported Transactional Data in DANA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('user_data_clean_ori.csv')

# %%
df[100:110]
# Out:
#      is_scammer  trx_date  report_date  registereddate  birthday  is_verified  \
# 100           1     19184        19315           17540     10597            1
# 101           1     19080        19086           17540        -1            0
# 102           1     18938        18695           17540      9503            1
# 103           1     19131        19136           17540      6217            1
# 104           1     19006        19015           17540      4754            1
# 105           1     19242        19190           17540      9142            1
# 106           1     19408        19411           17540     10600            1
# 107           1     19253        19002           17540     -4379            1
# 108           1     18725        18923           17540     10961            1
# 109           1     18780        18678           17540      6213            1
#
#      aqc_freq_prepaid_mobile  aqc_mean_prepaid_mobile_amount  aqc_freq_topup  \
# 100                        6                    2.150000e+16             107
# 101                        4                    3.260000e+16              44
# 102                       23                    1.540000e+16              95
# 103                        0                    0.000000e+00              17
# 104                        9                    5.860000e+15              86
# 105                       41                    2.570000e+15              17
# 106                       62                    2.090000e+16             271
# 107                       10                    6.510000e+15             147
# 108                        0                    0.000000e+00               8
# 109                       11                    3.950000e+16              60
#
#      aqc_freq_topup_within_7d  ...  gender_Null  job_position_KARYAWAN  \
# 100                        43  ...            0                      0
# 101                        16  ...            1                      0
# 102                        18  ...            0                      0
# 103                         2  ...            0                      0
# 104                         0  ...            0                      0
# 105                         0  ...            0                      0
# 106                         9  ...            0                      0
# 107                        93  ...            0                      0
# 108                         0  ...            0                      0
# 109                         2  ...            0                      1
#
#      job_position_LAINNYA  job_position_PEGAWAI_NS  job_position_PELAJAR  \
# 100                     0                        0                     0
# 101                     1                        0                     0
# 102                     0                        0                     0
# 103                     0                        0                     1
# 104                     0                        0                     0
# 105                     0                        0                     1
# 106                     0                        0                     1
# 107                     0                        0                     0
# 108                     0                        0                     0
# 109                     0                        0                     0
#
#      job_position_RUMAH_TANGGA  job_position_SPESIALIS  \
# 100                          0                       0
# 101                          0                       0
# 102                          0                       0
# 103                          0                       0
# 104                          0                       0
# 105                          0                       0
# 106                          0                       0
# 107                          1                       0
# 108                          0                       0
# 109                          0                       0
#
#      job_position_TIDAK_KERJA  job_position_WIRASWASTA  \
# 100                         1                        0
# 101                         0                        0
# 102                         1                        0
# 103                         0                        0
# 104                         0                        1
# 105                         0                        0
# 106                         0                        0
# 107                         0                        0
# 108                         1                        0
# 109                         0                        0
#
#                                       uid
# 100  f1fd4d59-e394-42ef-9d16-0f4ec7894c87
# 101  7a6f95d5-35b4-49f1-98b5-7408cd7c6a14
# 102  a5535fe3-0b98-419f-bd18-b81bef80dd45
# 103  7b1d0cc7-b389-472b-b457-cc4de9fe0070
# 104  ce6425a6-485f-4233-b62d-396b03c83375
# 105  60301634-3302-4e11-85f9-2ec639aec3b9
# 106  d30bcf65-c215-456b-8078-8ab25eb5031d
# 107  192126c9-1258-4a64-9ac2-87cd42030f3c
# 108  84914f97-2eb1-4fc6-a5b8-47bad721407f
# 109  d9462f34-6328-4ef3-a040-c17c2e48cfda
#
# [10 rows x 57 columns]

# %%
df['registereddate'].describe()
# Out:
# count    42859.000000
# mean     18471.174829
# std        970.659707
# min          0.000000
# 25%      18265.000000
# 50%      18631.000000
# 75%      18994.000000
# max      19360.000000
# Name: registereddate, dtype: float64

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

fig.suptitle('Date Time Data Distribution')

sns.histplot(ax=axes[0, 0], data=df['trx_date'], kde=True)
sns.histplot(ax=axes[0, 1], data=df['report_date'], kde=True)
sns.histplot(ax=axes[1, 0], data=df['registereddate'], kde=True)
sns.histplot(ax=axes[1, 1], data=df['birthday'], kde=True)
# Out:
# <AxesSubplot:xlabel='birthday', ylabel='Count'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

fig.suptitle('Date Time Data Distribution')

sns.histplot(ax=axes[0, 0], data=df['trx_date'], kde=True)
sns.histplot(ax=axes[0, 1], data=df['report_date'], kde=True)
sns.histplot(ax=axes[1, 0], data=df['registereddate'], kde=True)
sns.histplot(ax=axes[1, 1], data=df['birthday'], kde=True)
