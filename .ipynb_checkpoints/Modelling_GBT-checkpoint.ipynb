# %%
# !pip install tensorflow_decision_forests

# %%
import math
import urllib
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_decision_forests as tfdf

# %%
df = pd.read_csv("/content/drive/MyDrive/Capstone/datasets/user_data_test_cleaned.csv", sep=';')

# %%
df1 = df.drop(columns=['Unnamed: 0', 'uid'])

# %%
# Split Train and Validation Dataset
#from sklearn.model_selection import train_test_split
SPLIT_SIZE = 0.99

train_len = int(len(df1) * SPLIT_SIZE)

shuffled_files = df1.sample(frac = 1, random_state = 1)

test_set = shuffled_files[train_len:]
train_set = shuffled_files[:train_len]

y_train = train_set['is_scammer']
x_train = train_set.drop(columns=['is_scammer'])
y_test = test_set['is_scammer']
x_test = test_set.drop(columns=['is_scammer'])

# %%
test_set['weight'] = 1
train_set['weight'] = 1

# %%
NUMERIC_FEATURE_NAMES = np.array(x_train.columns)
# CATEGORICAL_FEATURE_NAMES = np.array(['is_scammer'])
# Target column name.
TARGET_COLUMN_NAME = "is_scammer"
# The labels of the target columns.
TARGET_LABELS = [1, 0]
# Weight column name.
WEIGHT_COLUMN_NAME = "weight"

# %%
# GBT HYPERPARAMETERS HERE
# Maximum number of decision trees. The effective number of trained trees can be smaller if early stopping is enabled.
NUM_TREES = 5
# Minimum number of examples in a node.
MIN_EXAMPLES = 8
# Maximum depth of the tree. max_depth=1 means that all trees will be roots.
MAX_DEPTH = 12
# Ratio of the dataset (sampling without replacement) used to train individual trees for the random sampling method.
SUBSAMPLE = 0.9
# Control the sampling of the datasets used to train individual trees.
SAMPLING_METHOD = "RANDOM"
# Ratio of the training dataset used to monitor the training. Require to be >0 if early stopping is enabled.
VALIDATION_RATIO = 0.73684

# %%
gbt_model = tfdf.keras.GradientBoostedTreesModel(
        num_trees=NUM_TREES,
        max_depth=MAX_DEPTH,
        min_examples=MIN_EXAMPLES,
        subsample=SUBSAMPLE,
        validation_ratio=VALIDATION_RATIO,
        task=tfdf.keras.Task.CLASSIFICATION,
    )
# Out:
# Use /tmp/tmp7hg4le8p as temporary training directory

# %%
gbt_model.compile(
        metrics=[
            tf.keras.metrics.Accuracy(),
            tf.keras.metrics.Precision(),
            tf.keras.metrics.Recall()
            ]
    )

# %%
gbt_model.fit(
        tfdf.keras.pd_dataframe_to_tf_dataset(train_set, label="is_scammer"), 
        epochs=1
    )
# Out:
# Reading training dataset...
# Training dataset read in 0:00:01.354523. Found 2120 examples.
# Training model...
# Model trained in 0:00:00.215876
# Compiling model...
# Model compiled.

# %%
gbt_model.summary()
# Out:
# Model: "gradient_boosted_trees_model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (51):
# 	aqc_freq_prepaid_mobile
# 	aqc_freq_topup
# 	aqc_freq_topup_within_7d
# 	aqc_freq_x2x
# 	aqc_freq_x2x_within_60d
# 	aqc_freq_x2x_within_90d
# 	aqc_mean_prepaid_mobile_amount
# 	aqc_mean_topup_amount
# 	aqc_mean_topup_amount_30d
# 	aqc_mean_topup_amount_7d
# 	aqc_mean_topup_amount_90d
# 	aqc_mean_x2x_amount
# 	aqc_mean_x2x_amount_30d
# 	aqc_mean_x2x_amount_60d
# 	aqc_mean_x2x_amount_7d
# 	aqc_mean_x2x_amount_90d
# 	aqc_total_topup_amount_7d
# 	aqc_total_topup_amount_90d
# 	aqc_total_x2x_amount
# 	aqc_total_x2x_amount_30d
# 	aqc_total_x2x_amount_60d
# 	aqc_total_x2x_amount_7d
# 	aqc_total_x2x_amount_90d
# 	avg_other_weight_1
# 	avg_topup_weight_1
# 	avg_x2x_weight_1
# 	birthday
# 	centrality_indegree_p2p
# 	centrality_outdegree_p2p
# 	centrality_outdegree_sendmoney
# 	centrality_undirected_p2p
# 	dormancy_count_trx
# 	dormancy_max_gmt_pay_diff_days
# 	dormancy_mean_gmt_pay_diff_days
# 	gender_Female
# 	gender_Male
# 	gender_None
# 	is_verified
# 	job_position_KARYAWAN
# 	job_position_LAINNYA
# 	job_position_PEGAWAI_NS
# 	job_position_PELAJAR
# 	job_position_RUMAH_TANGGA
# 	job_position_SPESIALIS
# 	job_position_TIDAK_KERJA
# 	job_position_WIRASWASTA
# 	kyc_total_failed
# 	kyc_total_revoked
# 	registereddate
# 	report_date
# 	trx_date
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1.                "avg_x2x_weight_1"  0.516129 ################
#     2.         "centrality_indegree_p2p"  0.276237 #####
#     3.                  "registereddate"  0.211248 ###
#     4.                        "trx_date"  0.177210 #
#     5.              "avg_topup_weight_1"  0.168300 #
#     6.                     "report_date"  0.151352
#     7.       "centrality_undirected_p2p"  0.148443
#     8.       "aqc_mean_topup_amount_30d"  0.144100
#     9.                        "birthday"  0.143383
#    10.             "aqc_mean_x2x_amount"  0.142669
#    11.        "aqc_total_x2x_amount_90d"  0.142641
#    12.          "aqc_mean_x2x_amount_7d"  0.140583
#    13.        "aqc_total_x2x_amount_30d"  0.140563
#    14.         "aqc_freq_x2x_within_60d"  0.140505
#    15.           "aqc_mean_topup_amount"  0.140387
#    16.         "aqc_freq_x2x_within_90d"  0.139662
#    17.        "aqc_freq_topup_within_7d"  0.139612
#    18.            "aqc_total_x2x_amount"  0.139415
#    19.  "dormancy_max_gmt_pay_diff_days"  0.139390
#    20.         "aqc_mean_x2x_amount_60d"  0.139196
#    21. "dormancy_mean_gmt_pay_diff_days"  0.138773
#    22.         "aqc_freq_prepaid_mobile"  0.138617
#    23.                    "aqc_freq_x2x"  0.138526
#    24.            "job_position_PELAJAR"  0.137889
#    25.      "aqc_total_topup_amount_90d"  0.137885
#    26.       "aqc_mean_topup_amount_90d"  0.137706
#    27.                  "aqc_freq_topup"  0.137668
#    28.  "centrality_outdegree_sendmoney"  0.137350
#    29.                "kyc_total_failed"  0.137306
#    30.       "aqc_total_topup_amount_7d"  0.136995
#    31.         "aqc_total_x2x_amount_7d"  0.135648
#    32.  "aqc_mean_prepaid_mobile_amount"  0.135587
#    33.        "aqc_mean_topup_amount_7d"  0.135056
#    34.              "avg_other_weight_1"  0.134685
#    35.         "aqc_mean_x2x_amount_90d"  0.134640
#    36.              "dormancy_count_trx"  0.134558
#    37.        "aqc_total_x2x_amount_60d"  0.134545
#    38.                     "is_verified"  0.134535
#    39.                     "gender_None"  0.134152
#    40.         "aqc_mean_x2x_amount_30d"  0.134094
#
# Variable Importance: NUM_AS_ROOT:
#     1.   "avg_x2x_weight_1"  4.000000 ################
#     2. "avg_topup_weight_1"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.                  "registereddate" 19.000000 ################
#     2.                "avg_x2x_weight_1" 16.000000 #############
#     3.                        "birthday" 11.000000 ########
#     4.  "dormancy_max_gmt_pay_diff_days"  9.000000 #######
#     5.                        "trx_date"  9.000000 #######
#     6.             "aqc_mean_x2x_amount"  8.000000 ######
#     7.       "aqc_total_topup_amount_7d"  8.000000 ######
#     8.              "avg_topup_weight_1"  8.000000 ######
#     9.                     "report_date"  8.000000 ######
#    10.            "aqc_total_x2x_amount"  7.000000 #####
#    11.         "centrality_indegree_p2p"  7.000000 #####
#    12. "dormancy_mean_gmt_pay_diff_days"  7.000000 #####
#    13.                    "aqc_freq_x2x"  6.000000 ####
#    14.           "aqc_mean_topup_amount"  6.000000 ####
#    15.      "aqc_total_topup_amount_90d"  6.000000 ####
#    16.  "aqc_mean_prepaid_mobile_amount"  5.000000 ###
#    17.       "aqc_mean_topup_amount_90d"  5.000000 ###
#    18.          "aqc_mean_x2x_amount_7d"  5.000000 ###
#    19.       "centrality_undirected_p2p"  5.000000 ###
#    20.                  "aqc_freq_topup"  4.000000 ##
#    21.        "aqc_mean_topup_amount_7d"  4.000000 ##
#    22.  "centrality_outdegree_sendmoney"  4.000000 ##
#    23.              "dormancy_count_trx"  4.000000 ##
#    24.         "aqc_freq_prepaid_mobile"  3.000000 #
#    25.        "aqc_freq_topup_within_7d"  3.000000 #
#    26.         "aqc_freq_x2x_within_60d"  3.000000 #
#    27.       "aqc_mean_topup_amount_30d"  3.000000 #
#    28.         "aqc_mean_x2x_amount_60d"  3.000000 #
#    29.         "aqc_total_x2x_amount_7d"  3.000000 #
#    30.        "aqc_total_x2x_amount_90d"  3.000000 #
#    31.              "avg_other_weight_1"  3.000000 #
#    32.         "aqc_freq_x2x_within_90d"  2.000000
#    33.        "aqc_total_x2x_amount_30d"  2.000000
#    34.        "aqc_total_x2x_amount_60d"  2.000000
#    35.            "job_position_PELAJAR"  2.000000
#    36.         "aqc_mean_x2x_amount_30d"  1.000000
#    37.         "aqc_mean_x2x_amount_90d"  1.000000
#    38.                     "gender_None"  1.000000
#    39.                     "is_verified"  1.000000
#    40.                "kyc_total_failed"  1.000000
#
# Variable Importance: SUM_SCORE:
#     1.                "avg_x2x_weight_1" 72.685696 ################
#     2.                  "registereddate" 47.666638 ##########
#     3.         "centrality_indegree_p2p" 47.498586 ##########
#     4.                        "trx_date" 16.549560 ###
#     5.              "avg_topup_weight_1" 16.457103 ###
#     6.      "aqc_total_topup_amount_90d" 10.270170 ##
#     7.       "centrality_undirected_p2p"  8.054510 #
#     8.                     "report_date"  7.359684 #
#     9.                    "aqc_freq_x2x"  7.166094 #
#    10.        "aqc_total_x2x_amount_90d"  6.476646 #
#    11.        "aqc_total_x2x_amount_30d"  6.122973 #
#    12.        "aqc_freq_topup_within_7d"  5.093263 #
#    13.  "centrality_outdegree_sendmoney"  4.980774 #
#    14.          "aqc_mean_x2x_amount_7d"  4.789385 #
#    15.            "aqc_total_x2x_amount"  4.782778 #
#    16.             "aqc_mean_x2x_amount"  4.699818 #
#    17.  "dormancy_max_gmt_pay_diff_days"  4.501928
#    18.       "aqc_mean_topup_amount_30d"  4.162501
#    19.                        "birthday"  4.141365
#    20.         "aqc_freq_prepaid_mobile"  4.094384
#    21.         "aqc_freq_x2x_within_60d"  3.960382
#    22.           "aqc_mean_topup_amount"  3.782635
#    23.       "aqc_total_topup_amount_7d"  3.736290
#    24.         "aqc_total_x2x_amount_7d"  3.384880
#    25. "dormancy_mean_gmt_pay_diff_days"  3.044277
#    26.              "dormancy_count_trx"  2.574656
#    27.         "aqc_mean_x2x_amount_60d"  2.545571
#    28.       "aqc_mean_topup_amount_90d"  2.381445
#    29.        "aqc_total_x2x_amount_60d"  1.590718
#    30.            "job_position_PELAJAR"  1.527235
#    31.         "aqc_mean_x2x_amount_90d"  1.259315
#    32.  "aqc_mean_prepaid_mobile_amount"  1.210402
#    33.              "avg_other_weight_1"  1.012007
#    34.                  "aqc_freq_topup"  0.772008
#    35.         "aqc_freq_x2x_within_90d"  0.585825
#    36.                     "gender_None"  0.277778
#    37.                "kyc_total_failed"  0.271811
#    38.         "aqc_mean_x2x_amount_30d"  0.241681
#    39.        "aqc_mean_topup_amount_7d"  0.022481
#    40.                     "is_verified"  0.001807
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 1.09339
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 5
# Total number of nodes: 421
#
# Number of nodes by tree:
# Count: 5 Average: 84.2 StdDev: 10.6283
# Min: 65 Max: 95 Ignored: 0
# ----------------------------------------------
# [ 65, 66) 1  20.00%  20.00% ##########
# [ 66, 68) 0   0.00%  20.00%
# [ 68, 69) 0   0.00%  20.00%
# [ 69, 71) 0   0.00%  20.00%
# [ 71, 72) 0   0.00%  20.00%
# [ 72, 74) 0   0.00%  20.00%
# [ 74, 75) 0   0.00%  20.00%
# [ 75, 77) 0   0.00%  20.00%
# [ 77, 78) 0   0.00%  20.00%
# [ 78, 80) 0   0.00%  20.00%
# [ 80, 82) 1  20.00%  40.00% ##########
# [ 82, 83) 0   0.00%  40.00%
# [ 83, 85) 0   0.00%  40.00%
# [ 85, 86) 0   0.00%  40.00%
# [ 86, 88) 0   0.00%  40.00%
# [ 88, 89) 0   0.00%  40.00%
# [ 89, 91) 1  20.00%  60.00% ##########
# [ 91, 92) 1  20.00%  80.00% ##########
# [ 92, 94) 0   0.00%  80.00%
# [ 94, 95] 1  20.00% 100.00% ##########
#
# Depth by leafs:
# Count: 213 Average: 6.50235 StdDev: 1.85286
# Min: 3 Max: 11 Ignored: 0
# ----------------------------------------------
# [  3,  4) 12   5.63%   5.63% ###
# [  4,  5) 24  11.27%  16.90% #####
# [  5,  6) 25  11.74%  28.64% #####
# [  6,  7) 47  22.07%  50.70% ##########
# [  7,  8) 37  17.37%  68.08% ########
# [  8,  9) 37  17.37%  85.45% ########
# [  9, 10) 23  10.80%  96.24% #####
# [ 10, 11)  4   1.88%  98.12% #
# [ 11, 11]  4   1.88% 100.00% #
#
# Number of training obs by leaf:
# Count: 213 Average: 11.2582 StdDev: 6.64908
# Min: 8 Max: 53 Ignored: 0
# ----------------------------------------------
# [  8, 10) 103  48.36%  48.36% ##########
# [ 10, 12)  50  23.47%  71.83% #####
# [ 12, 14)  29  13.62%  85.45% ###
# [ 14, 17)  23  10.80%  96.24% ##
# [ 17, 19)   0   0.00%  96.24%
# [ 19, 21)   0   0.00%  96.24%
# [ 21, 24)   0   0.00%  96.24%
# [ 24, 26)   0   0.00%  96.24%
# [ 26, 28)   1   0.47%  96.71%
# [ 28, 31)   1   0.47%  97.18%
# [ 31, 33)   0   0.00%  97.18%
# [ 33, 35)   0   0.00%  97.18%
# [ 35, 37)   0   0.00%  97.18%
# [ 37, 40)   1   0.47%  97.65%
# [ 40, 42)   0   0.00%  97.65%
# [ 42, 44)   0   0.00%  97.65%
# [ 44, 47)   1   0.47%  98.12%
# [ 47, 49)   2   0.94%  99.06%
# [ 49, 51)   1   0.47%  99.53%
# [ 51, 53]   1   0.47% 100.00%
#
# Attribute in nodes:
# 	19 : registereddate [NUMERICAL]
# 	16 : avg_x2x_weight_1 [NUMERICAL]
# 	11 : birthday [NUMERICAL]
# 	9 : trx_date [NUMERICAL]
# 	9 : dormancy_max_gmt_pay_diff_days [NUMERICAL]
# 	8 : report_date [NUMERICAL]
# 	8 : avg_topup_weight_1 [NUMERICAL]
# 	8 : aqc_total_topup_amount_7d [NUMERICAL]
# 	8 : aqc_mean_x2x_amount [NUMERICAL]
# 	7 : dormancy_mean_gmt_pay_diff_days [NUMERICAL]
# 	7 : centrality_indegree_p2p [NUMERICAL]
# 	7 : aqc_total_x2x_amount [NUMERICAL]
# 	6 : aqc_total_topup_amount_90d [NUMERICAL]
# 	6 : aqc_mean_topup_amount [NUMERICAL]
# 	6 : aqc_freq_x2x [NUMERICAL]
# 	5 : centrality_undirected_p2p [NUMERICAL]
# 	5 : aqc_mean_x2x_amount_7d [NUMERICAL]
# 	5 : aqc_mean_topup_amount_90d [NUMERICAL]
# 	5 : aqc_mean_prepaid_mobile_amount [NUMERICAL]
# 	4 : dormancy_count_trx [NUMERICAL]
# 	4 : centrality_outdegree_sendmoney [NUMERICAL]
# 	4 : aqc_mean_topup_amount_7d [NUMERICAL]
# 	4 : aqc_freq_topup [NUMERICAL]
# 	3 : avg_other_weight_1 [NUMERICAL]
# 	3 : aqc_total_x2x_amount_90d [NUMERICAL]
# 	3 : aqc_total_x2x_amount_7d [NUMERICAL]
# 	3 : aqc_mean_x2x_amount_60d [NUMERICAL]
# 	3 : aqc_mean_topup_amount_30d [NUMERICAL]
# 	3 : aqc_freq_x2x_within_60d [NUMERICAL]
# 	3 : aqc_freq_topup_within_7d [NUMERICAL]
# 	3 : aqc_freq_prepaid_mobile [NUMERICAL]
# 	2 : job_position_PELAJAR [NUMERICAL]
# 	2 : aqc_total_x2x_amount_60d [NUMERICAL]
# 	2 : aqc_total_x2x_amount_30d [NUMERICAL]
# 	2 : aqc_freq_x2x_within_90d [NUMERICAL]
# 	1 : kyc_total_failed [NUMERICAL]
# 	1 : is_verified [NUMERICAL]
# 	1 : gender_None [NUMERICAL]
# 	1 : aqc_mean_x2x_amount_90d [NUMERICAL]
# 	1 : aqc_mean_x2x_amount_30d [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	4 : avg_x2x_weight_1 [NUMERICAL]
# 	1 : avg_topup_weight_1 [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	5 : registereddate [NUMERICAL]
# 	5 : centrality_indegree_p2p [NUMERICAL]
# 	4 : avg_x2x_weight_1 [NUMERICAL]
# 	1 : avg_topup_weight_1 [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	8 : registereddate [NUMERICAL]
# 	5 : trx_date [NUMERICAL]
# 	5 : centrality_indegree_p2p [NUMERICAL]
# 	4 : avg_x2x_weight_1 [NUMERICAL]
# 	2 : report_date [NUMERICAL]
# 	2 : aqc_total_topup_amount_90d [NUMERICAL]
# 	2 : aqc_total_topup_amount_7d [NUMERICAL]
# 	1 : avg_topup_weight_1 [NUMERICAL]
# 	1 : aqc_mean_x2x_amount_7d [NUMERICAL]
# 	1 : aqc_mean_topup_amount_90d [NUMERICAL]
# 	1 : aqc_mean_topup_amount_30d [NUMERICAL]
# 	1 : aqc_freq_x2x_within_90d [NUMERICAL]
# 	1 : aqc_freq_x2x_within_60d [NUMERICAL]
# 	1 : aqc_freq_topup_within_7d [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	11 : registereddate [NUMERICAL]
# 	7 : avg_x2x_weight_1 [NUMERICAL]
# 	6 : trx_date [NUMERICAL]
# 	5 : centrality_indegree_p2p [NUMERICAL]
# 	3 : aqc_mean_x2x_amount [NUMERICAL]
# 	3 : aqc_mean_prepaid_mobile_amount [NUMERICAL]
# 	2 : report_date [NUMERICAL]
# 	2 : centrality_undirected_p2p [NUMERICAL]
# 	2 : aqc_total_topup_amount_90d [NUMERICAL]
# 	2 : aqc_total_topup_amount_7d [NUMERICAL]
# 	2 : aqc_mean_topup_amount [NUMERICAL]
# 	2 : aqc_freq_topup_within_7d [NUMERICAL]
# 	1 : job_position_PELAJAR [NUMERICAL]
# 	1 : gender_None [NUMERICAL]
# 	1 : dormancy_count_trx [NUMERICAL]
# 	1 : centrality_outdegree_sendmoney [NUMERICAL]
# 	1 : avg_topup_weight_1 [NUMERICAL]
# 	1 : aqc_total_x2x_amount_90d [NUMERICAL]
# 	1 : aqc_total_x2x_amount_30d [NUMERICAL]
# 	1 : aqc_mean_x2x_amount_7d [NUMERICAL]
# 	1 : aqc_mean_x2x_amount_60d [NUMERICAL]
# 	1 : aqc_mean_topup_amount_90d [NUMERICAL]
# 	1 : aqc_mean_topup_amount_30d [NUMERICAL]
# 	1 : aqc_freq_x2x_within_90d [NUMERICAL]
# 	1 : aqc_freq_x2x_within_60d [NUMERICAL]
# 	1 : aqc_freq_x2x [NUMERICAL]
# 	1 : aqc_freq_topup [NUMERICAL]
# 	1 : aqc_freq_prepaid_mobile [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	16 : registereddate [NUMERICAL]
# 	15 : avg_x2x_weight_1 [NUMERICAL]
# 	7 : trx_date [NUMERICAL]
# 	6 : centrality_indegree_p2p [NUMERICAL]
# 	6 : avg_topup_weight_1 [NUMERICAL]
# 	5 : report_date [NUMERICAL]
# 	5 : aqc_total_topup_amount_90d [NUMERICAL]
# 	5 : aqc_mean_x2x_amount [NUMERICAL]
# 	4 : dormancy_mean_gmt_pay_diff_days [NUMERICAL]
# 	4 : centrality_outdegree_sendmoney [NUMERICAL]
# 	4 : birthday [NUMERICAL]
# 	4 : aqc_total_topup_amount_7d [NUMERICAL]
# 	4 : aqc_mean_topup_amount [NUMERICAL]
# 	4 : aqc_mean_prepaid_mobile_amount [NUMERICAL]
# 	3 : dormancy_max_gmt_pay_diff_days [NUMERICAL]
# 	3 : centrality_undirected_p2p [NUMERICAL]
# 	3 : aqc_total_x2x_amount_90d [NUMERICAL]
# 	3 : aqc_mean_x2x_amount_7d [NUMERICAL]
# 	3 : aqc_mean_topup_amount_30d [NUMERICAL]
# 	3 : aqc_freq_x2x_within_60d [NUMERICAL]
# 	3 : aqc_freq_x2x [NUMERICAL]
# 	3 : aqc_freq_topup [NUMERICAL]
# 	3 : aqc_freq_prepaid_mobile [NUMERICAL]
# 	2 : dormancy_count_trx [NUMERICAL]
# 	2 : aqc_total_x2x_amount_7d [NUMERICAL]
# 	2 : aqc_total_x2x_amount_30d [NUMERICAL]
# 	2 : aqc_mean_x2x_amount_60d [NUMERICAL]
# 	2 : aqc_mean_topup_amount_90d [NUMERICAL]
# 	2 : aqc_freq_topup_within_7d [NUMERICAL]
# 	1 : kyc_total_failed [NUMERICAL]
# 	1 : job_position_PELAJAR [NUMERICAL]
# 	1 : gender_None [NUMERICAL]
# 	1 : aqc_total_x2x_amount_60d [NUMERICAL]
# 	1 : aqc_total_x2x_amount [NUMERICAL]
# 	1 : aqc_freq_x2x_within_90d [NUMERICAL]
#
# Condition type in nodes:
# 	208 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	5 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	15 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	35 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	63 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	134 : HigherCondition
#
# Training logs:
# Number of iteration to final model: 5
# 	Iter:1 train-loss:1.252566 valid-loss:1.297585  train-accuracy:0.874307 valid-accuracy:0.744142
# 	Iter:2 train-loss:1.141906 valid-loss:1.229981  train-accuracy:0.922366 valid-accuracy:0.762508
# 	Iter:3 train-loss:1.046882 valid-loss:1.175460  train-accuracy:0.942699 valid-accuracy:0.768208
# 	Iter:4 train-loss:0.966948 valid-loss:1.130863  train-accuracy:0.951941 valid-accuracy:0.775174
# 	Iter:5 train-loss:0.893035 valid-loss:1.093386  train-accuracy:0.957486 valid-accuracy:0.787207
